# %%
import ROOT

# %%
from FromSaved import PyHist_fromROOT

# %%
p1=PyHist_fromROOT("/home/ethan/Documents/ttZ/sept_minittv/nominal_output_0309_full.root","ttZ_spincorr_hel_nominal")

# %%
p1.__dict__
# Out:
# {'ROOT_hist': <cppyy.gbl.TH1D object at 0x55826c3ef630>,
#  'Xaxis_title': None,
#  'binning': array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  'branch_name': None,
#  'colour': None,
#  'errors': array([0.00203573, 0.00262197, 0.00305201, 0.00361547, 0.00483867,
#         0.00486461, 0.00409989, 0.0038085 , 0.00358048, 0.00381358]),
#  'file_name': None,
#  'individual_normalisation': True,
#  'name': '/home/ethan/Documents/ttZ/sept_minittv/nominal_output_0309_full.rootttZ_spincorr_hel_nominal',
#  'observable_error': None,
#  'observable_type': None,
#  'observable_value': None,
#  'x_bins': array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  'xaxis_label': None,
#  'xc_bins': array([-0.9, -0.7, -0.5, -0.3, -0.1,  0.1,  0.3,  0.5,  0.7,  0.9]),
#  'yaxis_label': None,
#  'ydata': array([0.02978013, 0.04940161, 0.06693571, 0.09393265, 0.16824381,
#         0.17005288, 0.12079043, 0.10423045, 0.09212357, 0.10450877,
# ...

# %%
p1.set_colour("blue")

# %%
p1.__dict__
# Out:
# {'ROOT_hist': <cppyy.gbl.TH1D object at 0x55826c3ef630>,
#  'Xaxis_title': None,
#  'binning': array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  'branch_name': None,
#  'colour': 'blue',
#  'errors': array([0.00203573, 0.00262197, 0.00305201, 0.00361547, 0.00483867,
#         0.00486461, 0.00409989, 0.0038085 , 0.00358048, 0.00381358]),
#  'file_name': None,
#  'individual_normalisation': True,
#  'name': '/home/ethan/Documents/ttZ/sept_minittv/nominal_output_0309_full.rootttZ_spincorr_hel_nominal',
#  'observable_error': None,
#  'observable_type': None,
#  'observable_value': None,
#  'x_bins': array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  'xaxis_label': None,
#  'xc_bins': array([-0.9, -0.7, -0.5, -0.3, -0.1,  0.1,  0.3,  0.5,  0.7,  0.9]),
#  'yaxis_label': None,
#  'ydata': array([0.02978013, 0.04940161, 0.06693571, 0.09393265, 0.16824381,
#         0.17005288, 0.12079043, 0.10423045, 0.09212357, 0.10450877,
# ...

# %%
from HistPlot1 import Seaborn_noratio as plot

# %%
plot([p1])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/ethan/.local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /home/ethan/.local/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     245
#     246     if 'png' in formats:
# --> 247         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     248     if 'retina' in formats or 'png2x' in formats:
#     249         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...
