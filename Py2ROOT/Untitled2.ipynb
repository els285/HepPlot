# %%
from FromSaved import PyHist_fromROOT as PP

# %%
import numpy as np
binning = np.linspace(0,500e3,51)

# %%
pyhist1 = PP("/home/ethan/Documents/ttZ/sept_minittv/pythia_outputs/final_combined/truth_spin1D_combined.root","ttZ_spincorr_hel_truth")

# %%
pyhist1.set_colour("blue")
pyhist1.set_legend_entry("Ckk")

# %%
from HistPlot_noratio import hist1dplot_NOratio as plot

# %%
plot([pyhist1])
